# %% [raw]
# ---
# title: "Clonal Analysis"
# subtitle: "scRNA-seq · Chapter 1"
# categories: [scRNA-seq, VDJ, Python]
# jupyter: dandelion
# ---

# %% [markdown]
# ## Test

# %% [markdown]
# ### Test

# %%
# Cell 2 — Code cell
import scanpy as sc
import matplotlib.pyplot as plt

# %%
sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
# Out:
# /tmp/ipykernel_1107653/1982427244.py:2: FutureWarning: Use `print_header` instead
#   sc.logging.print_versions()
# pytz	2025.2
# matplotlib-inline	0.1.7
# numba	0.61.0
# prompt_toolkit	3.0.52
# decorator	5.2.1
# jaraco.context	6.0.1
# jedi	0.19.2
# fastrlock	0.8.3
# pure_eval	0.2.3
# six	1.17.0
# cupy-cuda12x	13.6.0
# ipython	8.37.0
# debugpy	1.8.17
# asttokens	3.0.0
# jaraco.text	3.12.1
# joblib	1.5.2
# importlib_metadata	8.7.0
# jaraco.classes	3.4.0
# wcwidth	0.2.13
# stack_data	0.6.3
# pluggy	1.6.0
# jaraco.collections	5.1.0
# jaraco.functools	4.3.0
# texttable	1.7.0
# zstandard	0.23.0
# tornado	6.5.2
# parso	0.8.5
# backports.tarfile	1.2.0
# setuptools-scm	9.2.0
# tqdm	4.67.1
# kiwisolver	1.4.9
# psutil	7.1.0
# cffi	1.17.1
# pillow	10.3.0
# executing	2.2.1
# natsort	8.4.0
# PyYAML	6.0.2
# cycler	0.12.1
# ipywidgets	8.1.7
# defusedxml	0.7.1
# torch	2.5.1
# leidenalg	0.10.2
# llvmlite	0.44.0
# h5py	3.13.0
# pickleshare	0.7.5
# python-dateutil	2.9.0.post0
# protobuf	4.25.3
# zipp	3.23.0
# igraph	0.11.5
# setuptools	80.9.0
# ----	----
# Python	3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# OS	Linux-6.8.0-90-generic-x86_64-with-glibc2.39
# CPU	96 logical CPU cores, x86_64
# GPU	ID: 0, NVIDIA L40, Driver: 580.95.05, Memory: 46068 MiB
# Updated	2026-03-20 11:03

# %%
# Load example dataset (PBMC3k built-in)
adata = sc.datasets.pbmc3k_processed()
# Out:
#   0%|          | 0.00/23.5M [00:00<?, ?B/s]

# %%
# UMAP colored by cell type
sc.pl.umap(
    adata,
    color='louvain',
    title='PBMC 3k — Cell Types',
    frameon=False,
    legend_loc='on data'
)
